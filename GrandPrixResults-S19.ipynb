# %% [markdown]
# # GrandPrix Results Script
#
# This notebooks races a set of controllers in the folder Downloads/grandprix and then creates a movie of the race.

# %%
import glob
import os
import importlib
import sys
from grandprix import Sim
import numpy as np
import matplotlib.pyplot as plt
from contextlib import redirect_stdout
import io
# %matplotlib inline


def race(seed, race_name, print_failures=False, random_track=False):
    home=os.environ['HOME']
    path=os.path.join(home, "Downloads/grandprix")
    sys.path.insert(0, path)
    os.chdir(path)

    results = []
    data = {}
    modules = glob.glob("*.py")
    for i, f in enumerate(modules):
        if i % 10 == 0:
            print("{:4.0f} % complete".format(100*i/len(modules)))
        mod_name = f.split('.')[0]
        np.random.seed(seed)
        try:
            # set a trap and redirect stdout
            trap = io.StringIO()
            with redirect_stdout(trap):
                mod = importlib.import_module(mod_name)
                sim = Sim(mod.Controller)
                if random_track:
                    sim.track = np.round(3*np.random.rand(20) - 1.5)
                dist = sim.run()
                name = f.split('_')[1]
                results.append({
                    'name': name,
                    'dist': dist})
                data[name] = sim.data
        except Exception as e:
            if print_failures:
                print("{:s} failed with: {:s}".format(mod_name, str(e)))

    results = sorted(results, key=lambda x: x['dist'], reverse=True)

    place = 1
    j = 0
    while j < len(results):
        tie_count = 1
        i = 0
        while j + i + 1 < len(results):
            if results[j + i]['dist'] == results[j + i  + 1]['dist']:
                tie_count += 1
                i += 1
            else:
                break
        if tie_count > 1:
            for i in range(tie_count):
                results[j + i]['place'] = int(place + tie_count/2)
            j += tie_count
            place += tie_count
        else:
            results[j]['place'] = place
            place += 1
            j += 1

    n = len(results)
    for r in results:
        if r['place'] <= 0.25*n:
            r['points'] = 4
        elif r['place'] <= 0.5*n:
            r['points'] = 3
        elif r['place'] <= 0.75*n:
            r['points'] = 2
        else:
            r['points'] = 1

    with open('grandprix_{:s}.txt'.format(race_name), 'w') as f:
        for r in results:
            f.write("place: {:4d}\tpoints: {:4d}"
                    "\tname: {:15s}\tdistance: {:10.3f} m\n".format(
                r['place'], r['points'], r['name'], r['dist']))

    with open('grandprix_anon_{:s}.txt'.format(race_name), 'w') as f:
        for r in results:
            f.write("place: {:4d}\tpoints: {:4d}"
                    "\tdistance: {:10.3f} m\n".format(
                r['place'], r['points'], r['dist']))

    plt.figure(figsize=(10, 10))
    d = data[results[0]['name']]
    plt.plot(d['track_left_x'], d['track_left_y'], 'k', linewidth=1)
    plt.plot(d['track_right_x'], d['track_right_y'], 'k', linewidth=1)
    plt.grid()
    plt.axis('equal')
    place_last = 0
    for r in reversed(results):
        if r['place'] == place_last:
            continue
        else:
            place_last = r['place']
        d = data[r['name']]
        if r['place'] > 3:
            alpha = 0.1
        else:
            alpha = 0.9
        plt.plot(d['x'], d['y'], linewidth=2, alpha=alpha)
    plt.title('Grand Prix {:s}'.format(race_name))
    plt.xlabel('x, m')
    plt.ylabel('y, m')
    plt.savefig('{:s}.png'.format(race_name))
    return results, data

# %%
# %load_ext autoreload
# %autoreload 2
race_name = "grand_prix_2019"
# print_failures will show errors for controllers that do not run
results, data = race(6826, race_name, print_failures=True, random_track=False);
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#    0 % complete
#    8 % complete
#   15 % complete
#   23 % complete
# /home/jgoppert/anaconda3/envs/aae364/lib/python3.7/site-packages/scipy/sparse/linalg/matfuncs.py:716: LinAlgWarning: Ill-conditioned matrix (rcond=2.63506e-27): result may not be accurate.
#   return solve(Q, P)
#   31 % complete
#   38 % complete
#   46 % complete
#   53 % complete
#   61 % complete
#   69 % complete
#   76 % complete
# /home/jgoppert/anaconda3/envs/aae364/lib/python3.7/site-packages/scipy/optimize/optimize.py:570: RuntimeWarning: invalid value encountered in subtract
#   numpy.max(numpy.abs(fsim[0] - fsim[1:])) <= fatol):
#   84 % complete
#   92 % complete
#   99 % complete

# %%
def make_movie(race_name, results, data):
    from matplotlib import animation, rc
    # First set up the figure, the axis, and the plot element we want to animate

    fig = plt.figure(figsize=(10, 10))
    ax = plt.gca()
    interval = 10
    plt.axis('off')
    plt.axis('equal')
    #ax.set_xlim(( -1.75, 0.25))
    #ax.set_ylim((-0.5, 1.25))

    d = {
        'track_left_x': data[results[0]['name']]['track_left_x'],
        'track_left_y': data[results[0]['name']]['track_left_y'],
        'track_right_x': data[results[0]['name']]['track_right_x'],
        'track_right_y': data[results[0]['name']]['track_right_y'],
        'x': [],
        'y': []
    }

    for k in data.keys():
        d['x'].append(data[k]['x'])
        d['y'].append(data[k]['y'])
    for k in d.keys():
        d[k] = np.array(d[k]).T

    cars_line = []
    cars_dot = []
    place_last = 0
    for r in reversed(results):
        car_line, = ax.plot([], [], '-', alpha=0.1)
        car_dot, = ax.plot([], [], 'X', markersize=10, color=car_line.get_color(), alpha=1)
        cars_line.append(car_line)
        cars_dot.append(car_dot)

    line2, = ax.plot(d['track_left_x'], d['track_left_y'], 'k', lw=2)
    line3, = ax.plot(d['track_right_x'], d['track_right_y'], 'k', lw=2)

    # initialization function: plot the background of each frame
    def init():
        return (line2, line3)

    # animation function. This is called sequentially
    def animate(i):
        j = i*interval
        if j > len(d['x']) - 1:
            j = len(d['x']) - 1
        j0 = j-1000
        if j0 < 0:
            j0 = 0
        for i, (car_line, car_dot) in enumerate(zip(cars_line, cars_dot)):
            car_line.set_data(d['x'][j0:j, i], d['y'][j0:j, i])
            car_dot.set_data(d['x'][j, i], d['y'][j, i])
        return ()

    n = d['x'].shape[0]
    # call the animator. blit=True means only re-draw the parts that have changed.
    anim = animation.FuncAnimation(fig, animate, init_func=init,
                                   frames=n//interval + 10, interval=10*interval, blit=True)
    anim.save(race_name + '.mp4')
    plt.close()
    return anim
anim = make_movie(race_name, results, data)

# %%
from IPython.display import HTML
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# !cat /home/jgoppert/Desktop/results/grandprix_anon_grand_prix_2019.txt
# Out:
# place:    1	points:    4	distance:      5.394 m
# place:    2	points:    4	distance:      5.386 m
# place:    3	points:    4	distance:      5.312 m
# place:    4	points:    4	distance:      5.296 m
# place:    5	points:    4	distance:      5.290 m
# place:    6	points:    4	distance:      5.266 m
# place:    7	points:    4	distance:      5.220 m
# place:    8	points:    4	distance:      5.214 m
# place:    9	points:    4	distance:      5.194 m
# place:   10	points:    4	distance:      5.190 m
# place:   12	points:    4	distance:      5.182 m
# place:   12	points:    4	distance:      5.182 m
# place:   13	points:    4	distance:      5.154 m
# place:   14	points:    4	distance:      5.148 m
# place:   16	points:    4	distance:      5.146 m
# place:   16	points:    4	distance:      5.146 m
# place:   17	points:    4	distance:      5.134 m
# place:   18	points:    4	distance:      5.130 m
# place:   20	points:    4	distance:      5.128 m
# place:   20	points:    4	distance:      5.128 m
# place:   20	points:    4	distance:      5.128 m
# place:   22	points:    4	distance:      5.114 m
# place:   24	points:    4	distance:      5.106 m
# place:   24	points:    4	distance:      5.106 m
# place:   25	points:    4	distance:      5.104 m
# place:   27	points:    4	distance:      5.082 m
# place:   27	points:    4	distance:      5.082 m
# place:   28	points:    4	distance:      5.068 m
# place:   29	points:    4	distance:      4.986 m
# place:   30	points:    4	distance:      4.978 m
# place:   31	points:    4	distance:      4.922 m
# place:   32	points:    4	distance:      4.890 m
# place:   33	points:    3	distance:      4.850 m
# place:   34	points:    3	distance:      4.830 m
# place:   36	points:    3	distance:      4.828 m
# place:   36	points:    3	distance:      4.828 m
# place:   37	points:    3	distance:      4.748 m
# place:   38	points:    3	distance:      4.740 m
# place:   39	points:    3	distance:      4.736 m
# place:   40	points:    3	distance:      4.724 m
# place:   41	points:    3	distance:      4.700 m
# place:   42	points:    3	distance:      4.682 m
# place:   43	points:    3	distance:      4.660 m
# place:   44	points:    3	distance:      4.644 m
# place:   45	points:    3	distance:      4.632 m
# place:   46	points:    3	distance:      4.622 m
# place:   47	points:    3	distance:      4.590 m
# place:   48	points:    3	distance:      4.576 m
# place:   49	points:    3	distance:      4.562 m
# place:   50	points:    3	distance:      4.548 m
# place:   51	points:    3	distance:      4.546 m
# place:   52	points:    3	distance:      4.540 m
# place:   54	points:    3	distance:      4.534 m
# place:   54	points:    3	distance:      4.534 m
# place:   55	points:    3	distance:      4.524 m
# place:   56	points:    3	distance:      4.518 m
# place:   57	points:    3	distance:      4.516 m
# place:   58	points:    3	distance:      4.512 m
# place:   60	points:    3	distance:      4.510 m
# place:   60	points:    3	distance:      4.510 m
# place:   61	points:    3	distance:      4.506 m
# place:   62	points:    3	distance:      4.480 m
# place:   63	points:    3	distance:      4.426 m
# place:   64	points:    3	distance:      4.398 m
# place:   65	points:    3	distance:      4.340 m
# place:   66	points:    2	distance:      4.236 m
# place:   67	points:    2	distance:      4.218 m
# place:   68	points:    2	distance:      4.178 m
# place:   69	points:    2	distance:      4.144 m
# place:   71	points:    2	distance:      4.074 m
# place:   71	points:    2	distance:      4.074 m
# place:   72	points:    2	distance:      4.050 m
# place:   73	points:    2	distance:      3.998 m
# place:   74	points:    2	distance:      3.560 m
# place:   75	points:    2	distance:      3.504 m
# place:   76	points:    2	distance:      3.466 m
# place:   78	points:    2	distance:      3.458 m
# place:   78	points:    2	distance:      3.458 m
# place:   79	points:    2	distance:      3.330 m
# place:   80	points:    2	distance:      3.278 m
# place:   81	points:    2	distance:      3.214 m
# place:   82	points:    2	distance:      3.186 m
# place:   83	points:    2	distance:      3.176 m
# place:   84	points:    2	distance:      3.074 m
# place:   85	points:    2	distance:      3.060 m
# place:   86	points:    2	distance:      2.988 m
# place:   88	points:    2	distance:      2.858 m
# place:   88	points:    2	distance:      2.858 m
# place:   89	points:    2	distance:      2.792 m
# place:   90	points:    2	distance:      2.714 m
# place:   91	points:    2	distance:      2.650 m
# place:   93	points:    2	distance:      2.644 m
# place:   93	points:    2	distance:      2.644 m
# place:   94	points:    2	distance:      2.608 m
# place:   95	points:    2	distance:      2.588 m
# place:   96	points:    2	distance:      2.578 m
# place:   97	points:    2	distance:      2.568 m
# place:   98	points:    2	distance:      2.520 m
# place:   99	points:    1	distance:      2.510 m
# place:  100	points:    1	distance:      2.462 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  112	points:    1	distance:      2.358 m
# place:  123	points:    1	distance:      2.298 m
# place:  124	points:    1	distance:      1.916 m
# place:  125	points:    1	distance:      1.748 m
# place:  126	points:    1	distance:      1.390 m
# place:  127	points:    1	distance:      0.868 m
# place:  128	points:    1	distance:      0.690 m
# place:  129	points:    1	distance:      0.592 m
# place:  130	points:    1	distance:      0.316 m
# place:  131	points:    1	distance:      0.068 m

# %%
race_name = "grand_prix_2019_alt"
# print_failures will show errors for controllers that do not run
results, data = race(9145, race_name, print_failures=True, random_track=True);
# Out:
#    0 % complete
#    8 % complete
#   15 % complete
#   23 % complete
# /home/jgoppert/anaconda3/envs/aae364/lib/python3.7/site-packages/scipy/sparse/linalg/matfuncs.py:716: LinAlgWarning: Ill-conditioned matrix (rcond=2.63506e-27): result may not be accurate.
#   return solve(Q, P)
#   31 % complete
#   38 % complete
#   46 % complete
#   53 % complete
#   61 % complete
#   69 % complete
#   76 % complete
# /home/jgoppert/anaconda3/envs/aae364/lib/python3.7/site-packages/scipy/optimize/optimize.py:570: RuntimeWarning: invalid value encountered in subtract
#   numpy.max(numpy.abs(fsim[0] - fsim[1:])) <= fatol):
#   84 % complete
#   92 % complete
#   99 % complete

# %%
anim2 = make_movie(race_name, results, data)

# %%
HTML(anim2.to_html5_video())
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# !cat /home/jgoppert/Desktop/results/grandprix_anon_grand_prix_2019_alt.txt
# Out:
# place:    1	points:    4	distance:      5.016 m
# place:    2	points:    4	distance:      5.002 m
# place:    3	points:    4	distance:      4.990 m
# place:    4	points:    4	distance:      4.964 m
# place:    5	points:    4	distance:      4.962 m
# place:    6	points:    4	distance:      4.960 m
# place:    7	points:    4	distance:      4.958 m
# place:    8	points:    4	distance:      4.956 m
# place:    9	points:    4	distance:      4.954 m
# place:   10	points:    4	distance:      4.946 m
# place:   12	points:    4	distance:      4.940 m
# place:   12	points:    4	distance:      4.940 m
# place:   13	points:    4	distance:      4.882 m
# place:   14	points:    4	distance:      4.876 m
# place:   15	points:    4	distance:      4.846 m
# place:   17	points:    4	distance:      4.666 m
# place:   17	points:    4	distance:      4.666 m
# place:   17	points:    4	distance:      4.666 m
# place:   19	points:    4	distance:      4.636 m
# place:   21	points:    4	distance:      4.626 m
# place:   21	points:    4	distance:      4.626 m
# place:   22	points:    4	distance:      4.504 m
# place:   23	points:    4	distance:      4.470 m
# place:   24	points:    4	distance:      4.420 m
# place:   25	points:    4	distance:      4.390 m
# place:   26	points:    4	distance:      4.384 m
# place:   27	points:    4	distance:      4.358 m
# place:   28	points:    4	distance:      4.332 m
# place:   29	points:    4	distance:      4.242 m
# place:   30	points:    4	distance:      4.188 m
# place:   31	points:    4	distance:      4.166 m
# place:   32	points:    4	distance:      4.074 m
# place:   33	points:    3	distance:      4.066 m
# place:   34	points:    3	distance:      4.054 m
# place:   35	points:    3	distance:      3.888 m
# place:   36	points:    3	distance:      3.852 m
# place:   37	points:    3	distance:      3.746 m
# place:   38	points:    3	distance:      3.724 m
# place:   40	points:    3	distance:      3.522 m
# place:   40	points:    3	distance:      3.522 m
# place:   41	points:    3	distance:      3.494 m
# place:   42	points:    3	distance:      3.200 m
# place:   43	points:    3	distance:      3.190 m
# place:   44	points:    3	distance:      3.032 m
# place:   45	points:    3	distance:      3.028 m
# place:   46	points:    3	distance:      2.954 m
# place:   47	points:    3	distance:      2.940 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   59	points:    3	distance:      2.922 m
# place:   70	points:    2	distance:      2.882 m
# place:   71	points:    2	distance:      2.842 m
# place:   72	points:    2	distance:      2.824 m
# place:   73	points:    2	distance:      2.736 m
# place:   74	points:    2	distance:      2.722 m
# place:   75	points:    2	distance:      2.704 m
# place:   76	points:    2	distance:      2.698 m
# place:   77	points:    2	distance:      2.686 m
# place:   78	points:    2	distance:      2.684 m
# place:   79	points:    2	distance:      2.672 m
# place:   80	points:    2	distance:      2.644 m
# place:   81	points:    2	distance:      2.640 m
# place:   82	points:    2	distance:      2.636 m
# place:   83	points:    2	distance:      2.594 m
# place:   84	points:    2	distance:      2.578 m
# place:   85	points:    2	distance:      2.576 m
# place:   87	points:    2	distance:      2.554 m
# place:   87	points:    2	distance:      2.554 m
# place:   88	points:    2	distance:      2.552 m
# place:   89	points:    2	distance:      2.540 m
# place:   90	points:    2	distance:      2.520 m
# place:   91	points:    2	distance:      2.488 m
# place:   92	points:    2	distance:      2.480 m
# place:   94	points:    2	distance:      2.478 m
# place:   94	points:    2	distance:      2.478 m
# place:   94	points:    2	distance:      2.478 m
# place:   96	points:    2	distance:      2.468 m
# place:   97	points:    2	distance:      2.464 m
# place:   98	points:    2	distance:      2.450 m
# place:  100	points:    1	distance:      2.434 m
# place:  100	points:    1	distance:      2.434 m
# place:  101	points:    1	distance:      2.432 m
# place:  102	points:    1	distance:      2.404 m
# place:  103	points:    1	distance:      2.398 m
# place:  104	points:    1	distance:      2.368 m
# place:  105	points:    1	distance:      2.354 m
# place:  106	points:    1	distance:      2.290 m
# place:  108	points:    1	distance:      2.270 m
# place:  108	points:    1	distance:      2.270 m
# place:  109	points:    1	distance:      2.246 m
# place:  110	points:    1	distance:      2.232 m
# place:  111	points:    1	distance:      2.222 m
# place:  112	points:    1	distance:      2.150 m
# place:  113	points:    1	distance:      2.116 m
# place:  114	points:    1	distance:      2.052 m
# place:  115	points:    1	distance:      2.012 m
# place:  116	points:    1	distance:      1.802 m
# place:  117	points:    1	distance:      1.562 m
# place:  118	points:    1	distance:      1.306 m
# place:  119	points:    1	distance:      0.966 m
# place:  120	points:    1	distance:      0.800 m
# place:  121	points:    1	distance:      0.764 m
# place:  122	points:    1	distance:      0.674 m
# place:  124	points:    1	distance:      0.664 m
# place:  124	points:    1	distance:      0.664 m
# place:  125	points:    1	distance:      0.640 m
# place:  126	points:    1	distance:      0.578 m
# place:  127	points:    1	distance:      0.530 m
# place:  129	points:    1	distance:      0.524 m
# place:  129	points:    1	distance:      0.524 m
# place:  130	points:    1	distance:      0.320 m
# place:  131	points:    1	distance:      0.046 m
